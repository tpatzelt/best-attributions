# %%
import json
import numpy as np
from matplotlib import pyplot as plt

# %%
with open("../data/random_one_sample-softmax.json", "r") as fp:
    one_sample_softmax_results = json.load(fp)
    
with open("../data/random_all_samples-softmax.json", "r") as fp:
    all_sample_softmax_results = json.load(fp)

with open("../data/random_all_samples.json", "r") as fp:
    all_sample_logits_results = json.load(fp)
    
with open("../data/random_one_sample.json", "r") as fp:
    one_sample_logits_results = json.load(fp)

# %%
plt.rcParams["figure.figsize"] = (20,3)

# %%
random_tpns = one_sample_softmax_results['random_tpn_results']
random_tpss = one_sample_softmax_results['random_tps_results']
lig_tpn = one_sample_softmax_results['lig_tpn'][0]
lig_tps = one_sample_softmax_results['lig_tps'][0]

fig, ax = plt.subplots()

ax.plot(random_tpns)
ax.plot([lig_tpn] * len(random_tpns))
#ax.set_xlim([0, 1])
#ax.set_ylim([0,1])
ax.set(xlabel='iteration', ylabel='tpn score',
       title='TPN on Random Attribution Values for one sample')
#ax.grid()

#fig.savefig("data/tpn_example_calculation.png")
plt.show()

fig, ax = plt.subplots()

ax.plot(random_tpss)
ax.plot([lig_tps] * len(random_tpns))
#ax.set_xlim([0, 1])
#ax.set_ylim([0,1])
ax.set(xlabel='iteration', ylabel='tpn score',
       title='TPS on Random Attribution Values for one sample')
#ax.grid()

#fig.savefig("data/tpn_example_calculation.png")
plt.show()

# %%
random_tpns = one_sample_logits_results['random_tpn_results']
random_tpss = one_sample_logits_results['random_tps_results']
lig_tpn = one_sample_logits_results['lig_tpn']
lig_tps = one_sample_logits_results['lig_tps']

fig, ax = plt.subplots()

ax.plot(random_tpns)
ax.plot([lig_tpn] * len(random_tpns))
#ax.set_xlim([0, 1])
#ax.set_ylim([0,1])
ax.set(xlabel='iteration', ylabel='tpn score',
       title='TPN on Random Attribution Values for one sample')
#ax.grid()

#fig.savefig("data/tpn_example_calculation.png")
plt.show()

fig, ax = plt.subplots()

ax.plot(random_tpss)
ax.plot([lig_tps] * len(random_tpns))
#ax.set_xlim([0, 1])
#ax.set_ylim([0,1])
ax.set(xlabel='iteration', ylabel='tpn score',
       title='TPS on Random Attribution Values for one sample')
#ax.grid()

#fig.savefig("data/tpn_example_calculation.png")
plt.show()

# %%
random_tpns, lig_tpns = zip(*all_sample_softmax_results['tpn_results'])
random_tpss, lig_tpss = zip(*all_sample_softmax_results['tps_results'])

fig, ax = plt.subplots()

ax.plot(random_tpns)
ax.plot(lig_tpss)
#ax.set_xlim([0, 1])
#ax.set_ylim([0,1])
ax.set(xlabel='iteration', ylabel='tpn score',
       title='TPN on Random Attribution Values and LIG')
#ax.grid()

#fig.savefig("data/tpn_example_calculation.png")
plt.show()

fig, ax = plt.subplots()

ax.plot(random_tpss)
ax.plot(lig_tpss)
#ax.set_xlim([0, 1])
#ax.set_ylim([0,1])
ax.set(xlabel='iteration', ylabel='tpn score',
       title='TPS on Random Attribution Values and LIG')
#ax.grid()

#fig.savefig("data/tpn_example_calculation.png")
plt.show()

# %%
random_tpns, lig_tpns = zip(*all_sample_logits_results['tpn_results'])
random_tpss, lig_tpss = zip(*all_sample_logits_results['tps_results'])

fig, ax = plt.subplots()

ax.plot(random_tpns)
ax.plot(lig_tpss)
#ax.set_xlim([0, 1])
#ax.set_ylim([0,1])
ax.set(xlabel='iteration', ylabel='tpn score',
       title='TPN on Random Attribution Values and LIG')
#ax.grid()

#fig.savefig("data/tpn_example_calculation.png")
plt.show()

fig, ax = plt.subplots()

ax.plot(random_tpss)
ax.plot(lig_tpss)
#ax.set_xlim([0, 1])
#ax.set_ylim([0,1])
ax.set(xlabel='iteration', ylabel='tpn score',
       title='TPS on Random Attribution Values and LIG')
#ax.grid()

#fig.savefig("data/tpn_example_calculation.png")
plt.show()

# %%
all_sample_logits_results
# Out:
# {'tpn_results': [], 'tps_results': []}
